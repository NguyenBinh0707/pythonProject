# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenBinh0707/pythonProject/blob/master/%C4%90%E1%BB%93_%C3%A1n_m%C3%B4_t%E1%BA%A3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np 
from scipy.stats import t
import pandas as pd
import xlrd
from scipy import stats
from statsmodels.stats.weightstats import ztest
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('/content/drive/MyDrive/Baitap/Inc_Exp_Data.csv')
df
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %% [markdown]
# Vậy ta thấy rằng bảng dữ liệu này có 50 hàng, và 7 cột lần lượt là Mthly_HH_Income,
#
# Mthly_HH_Expense, (định lượng)
#
# No_of_Fly_Members,(định lượng)
#
# Emi_or_Rent_Amt,(định lượng)
#
# Annual_HH_Income,(định lượng)
#
# Highest_Qualified_Member,(định tính)
#
# No_of_Earning_Members,(định lượng)

# %%
df.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %%
df.describe()
a= ['Mthly_HH_Income','Mthly_HH_Expense', 'No_of_Fly_Members','Emi_or_Rent_Amt', 'Annual_HH_Income','No_of_Earning_Members','Highest_Qualified_Member'	 ]

# %%
for i in range(len(a)):
  print("Name of col " , a[i])
  plt.boxplot(df[a[i]])
  plt.show()
# Out:
# Name of col  Mthly_HH_Income
# Name of col  Mthly_HH_Expense
# Name of col  No_of_Fly_Members
# Name of col  Emi_or_Rent_Amt
# Name of col  Annual_HH_Income
# Name of col  No_of_Earning_Members

# %%
for i in range(len(a)):
  print("Name of col " , a[i])
  label = list(set(df[a[i]]))
  plt.figure(figsize=(50,50))
  count = df[a[i]].value_counts(sort=False).to_numpy() 
  plt.bar(label, count)
  plt.show()
# Out:
# Name of col  Mthly_HH_Income
# Name of col  Mthly_HH_Expense
# Name of col  No_of_Fly_Members
# Name of col  Emi_or_Rent_Amt
# Name of col  Annual_HH_Income
# Name of col  No_of_Earning_Members
# Name of col  Highest_Qualified_Member

# %%
for i in range(len(a)):
  print("Name of col " , a[i])
  plt.hist(df[a[i]], bins = 100)
  plt.show()
# Out:
# Name of col  Mthly_HH_Income
# Name of col  Mthly_HH_Expense
# Name of col  No_of_Fly_Members
# Name of col  Emi_or_Rent_Amt
# Name of col  Annual_HH_Income
# Name of col  No_of_Earning_Members
# Name of col  Highest_Qualified_Member
